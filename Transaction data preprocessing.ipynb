# %% [markdown]
# # importing library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_transactions=pd.read_csv('transaction.csv')

# %%
df_accounts=pd.read_csv('final_accounts')

# %%
df_accounts
# Out:
#         Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                0       1      Monthly        Arrear     Closed      48
# 1                1       2      Monthly       Advance     Closed      47
# 2                2       3      Quatrly        Arrear     Active      68
# 3                3       7      Monthly       Advance     Closed      48
# 4                4       8      Monthly        Arrear     Closed      44
# ...            ...     ...          ...           ...        ...     ...
# 121042      128648  143388      Quatrly        Arrear     Active      24
# 121043      128649  143389      Quatrly        Arrear     Closed      12
# 121044      128650  143390  Half Yearly        Arrear     Closed      24
# 121045      128651  143391  Half Yearly        Arrear     Closed      24
# 121046      128653  143394  Half Yearly        Arrear     Active      35
#
#         AssetCost  AmountFinance  DisbursalAmount      EMI DisbursalDate  \
# ...

# %%
df_transactions
# Out:
#             ID  SELF-INDICATOR MATCH-TYPE             ACCT-TYPE  \
# 0            1           False    PRIMARY             Overdraft
# 1            1           False    PRIMARY  Auto Loan (Personal)
# 2            1            True    PRIMARY          Tractor Loan
# 3            1            True    PRIMARY  Auto Loan (Personal)
# 4            1            True    PRIMARY          Tractor Loan
# ...        ...             ...        ...                   ...
# 560839  143393           False    PRIMARY          Tractor Loan
# 560840  143393           False    PRIMARY          Tractor Loan
# 560841  143393           False    PRIMARY  Auto Loan (Personal)
# 560842  143394            True    PRIMARY          Tractor Loan
# 560843  143395            True    PRIMARY          Tractor Loan
#
#        CONTRIBUTOR-TYPE DATE-REPORTED OWNERSHIP-IND ACCOUNT-STATUS  \
# 0                   NAB    2018-04-30    Individual     Delinquent
# ...

# %% [markdown]
# # megering dataset

# %%
df_new=pd.merge(df_accounts,df_transactions,how='inner',on='ID')

# %%
df_new.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Frequency', 'InstlmentMode', 'LoanStatus',
#        'Tenure', 'AssetCost', 'AmountFinance', 'DisbursalAmount', 'EMI',
#        'DisbursalDate', 'LTV', 'AGE', 'MonthlyIncome', 'State', 'Top-up Month',
#        'Feedback', 'Target', 'new_emi1', 'capable1', 'SELF-INDICATOR',
#        'MATCH-TYPE', 'ACCT-TYPE', 'CONTRIBUTOR-TYPE', 'DATE-REPORTED',
#        'OWNERSHIP-IND', 'ACCOUNT-STATUS', 'DISBURSED-DT', 'CLOSE-DT',
#        'LAST-PAYMENT-DATE', 'CREDIT-LIMIT/SANC AMT',
#        'DISBURSED-AMT/HIGH CREDIT', 'INSTALLMENT-AMT', 'CURRENT-BAL',
#        'INSTALLMENT-FREQUENCY', 'OVERDUE-AMT', 'WRITE-OFF-AMT', 'ASSET_CLASS',
#        'REPORTED DATE - HIST', 'DPD - HIST', 'CUR BAL - HIST',
#        'AMT OVERDUE - HIST', 'AMT PAID - HIST', 'TENURE'],
#       dtype='object')

# %%
df_new['OVERDUE-AMT']=df_new['OVERDUE-AMT'].fillna(0)

# %%
df_new['WRITE-OFF-AMT'].describe()
# Out:
# count    4.967820e+05
# mean     2.720972e+02
# std      1.548562e+04
# min     -3.000000e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      7.000000e+06
# Name: WRITE-OFF-AMT, dtype: float64

# %%
df_new.groupby(['ID','WRITE-OFF-AMT']).size()
# Out:
# ID      WRITE-OFF-AMT
# 1       0.0               9
# 2       0.0              13
# 3       0.0              31
# 7       0.0               4
# 8       0.0               7
#                          ..
# 143388  0.0               2
# 143389  0.0               4
# 143390  0.0               2
# 143391  0.0               1
# 143394  0.0               1
# Length: 122015, dtype: int64

# %%
df_new
# Out:
#         Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                0       1      Monthly        Arrear     Closed      48
# 1                0       1      Monthly        Arrear     Closed      48
# 2                0       1      Monthly        Arrear     Closed      48
# 3                0       1      Monthly        Arrear     Closed      48
# 4                0       1      Monthly        Arrear     Closed      48
# ...            ...     ...          ...           ...        ...     ...
# 514131      128649  143389      Quatrly        Arrear     Closed      12
# 514132      128650  143390  Half Yearly        Arrear     Closed      24
# 514133      128650  143390  Half Yearly        Arrear     Closed      24
# 514134      128651  143391  Half Yearly        Arrear     Closed      24
# 514135      128653  143394  Half Yearly        Arrear     Active      35
#
#         AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new['WRITE-OFF-AMT'][126212]
# Out:
# 0.0

# %%
df_new.drop_duplicates()
# Out:
#         Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                0       1      Monthly        Arrear     Closed      48
# 1                0       1      Monthly        Arrear     Closed      48
# 2                0       1      Monthly        Arrear     Closed      48
# 3                0       1      Monthly        Arrear     Closed      48
# 4                0       1      Monthly        Arrear     Closed      48
# ...            ...     ...          ...           ...        ...     ...
# 514131      128649  143389      Quatrly        Arrear     Closed      12
# 514132      128650  143390  Half Yearly        Arrear     Closed      24
# 514133      128650  143390  Half Yearly        Arrear     Closed      24
# 514134      128651  143391  Half Yearly        Arrear     Closed      24
# 514135      128653  143394  Half Yearly        Arrear     Active      35
#
#         AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new.isna().sum()/df_new.shape[0]*100
# Out:
# Unnamed: 0                    0.000000
# ID                            0.000000
# Frequency                     0.000000
# InstlmentMode                 0.000000
# LoanStatus                    0.000000
# Tenure                        0.000000
# AssetCost                     0.000000
# AmountFinance                 0.000000
# DisbursalAmount               0.000000
# EMI                           0.000000
# DisbursalDate                 0.000000
# LTV                           0.000000
# AGE                           0.000000
# MonthlyIncome                 0.113978
# State                         0.000000
# Top-up Month                  0.000000
# Feedback                      0.000000
# Target                        0.000000
# new_emi1                      0.000000
# capable1                      0.000000
# SELF-INDICATOR                0.000000
# MATCH-TYPE                    0.000000
# ACCT-TYPE                     0.000000
# CONTRIBUTOR-TYPE              0.000000
# ...

# %%
df_new['OVERDUE-AMT'].value_counts()
# Out:
# 0           375593
# 0           107623
# 118            235
# 1              130
# 100             83
#              ...
# 14,517           1
# 52,332           1
# 1,59,769         1
# 1,09,923         1
# 15,447           1
# Name: OVERDUE-AMT, Length: 20975, dtype: int64

# %%
df=df_new.groupby(['ID','OVERDUE-AMT']).size().reset_index()

# %%
df
# Out:
#             ID OVERDUE-AMT   0
# 0            1           0   3
# 1            1           0   5
# 2            1      37,873   1
# 3            2           0   1
# 4            2           0  12
# ...        ...         ...  ..
# 184210  143389           0   1
# 184211  143389           0   3
# 184212  143390           0   2
# 184213  143391           0   1
# 184214  143394           0   1
#
# [184215 rows x 3 columns]

# %%
df_new1=pd.merge(df_new,df,how='inner',on='ID')

# %%
df_new1
# Out:
#          Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                 0       1      Monthly        Arrear     Closed      48
# 1                 0       1      Monthly        Arrear     Closed      48
# 2                 0       1      Monthly        Arrear     Closed      48
# 3                 0       1      Monthly        Arrear     Closed      48
# 4                 0       1      Monthly        Arrear     Closed      48
# ...             ...     ...          ...           ...        ...     ...
# 1092595      128649  143389      Quatrly        Arrear     Closed      12
# 1092596      128650  143390  Half Yearly        Arrear     Closed      24
# 1092597      128650  143390  Half Yearly        Arrear     Closed      24
# 1092598      128651  143391  Half Yearly        Arrear     Closed      24
# 1092599      128653  143394  Half Yearly        Arrear     Active      35
#
#          AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new.isna().sum()
# Out:
# Unnamed: 0                        0
# ID                                0
# Frequency                         0
# InstlmentMode                     0
# LoanStatus                        0
# Tenure                            0
# AssetCost                         0
# AmountFinance                     0
# DisbursalAmount                   0
# EMI                               0
# DisbursalDate                     0
# LTV                               0
# AGE                               0
# MonthlyIncome                   586
# State                             0
# Top-up Month                      0
# Feedback                          0
# Target                            0
# new_emi1                          0
# capable1                          0
# SELF-INDICATOR                    0
# MATCH-TYPE                        0
# ACCT-TYPE                         0
# CONTRIBUTOR-TYPE                  0
# DATE-REPORTED                  3288
# OWNERSHIP-IND                     0
# ...

# %%
df_new
# Out:
#         Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                0       1      Monthly        Arrear     Closed      48
# 1                0       1      Monthly        Arrear     Closed      48
# 2                0       1      Monthly        Arrear     Closed      48
# 3                0       1      Monthly        Arrear     Closed      48
# 4                0       1      Monthly        Arrear     Closed      48
# ...            ...     ...          ...           ...        ...     ...
# 514131      128649  143389      Quatrly        Arrear     Closed      12
# 514132      128650  143390  Half Yearly        Arrear     Closed      24
# 514133      128650  143390  Half Yearly        Arrear     Closed      24
# 514134      128651  143391  Half Yearly        Arrear     Closed      24
# 514135      128653  143394  Half Yearly        Arrear     Active      35
#
#         AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new.drop(['SELF-INDICATOR', 'MATCH-TYPE', 'ACCT-TYPE', 'CONTRIBUTOR-TYPE', 'DATE-REPORTED',
    'OWNERSHIP-IND', 'DISBURSED-DT', 'CLOSE-DT', 'LAST-PAYMENT-DATE',
    'CREDIT-LIMIT/SANC AMT', 'DISBURSED-AMT/HIGH CREDIT', 'INSTALLMENT-AMT', 'CURRENT-BAL',
    'INSTALLMENT-FREQUENCY', 'ASSET_CLASS', 'REPORTED DATE - HIST',
    'DPD - HIST', 'CUR BAL - HIST', 'AMT PAID - HIST','TENURE','AMT OVERDUE - HIST'],axis=1,inplace=True)

# %%
df_new1
# Out:
#          Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                 0       1      Monthly        Arrear     Closed      48
# 1                 0       1      Monthly        Arrear     Closed      48
# 2                 0       1      Monthly        Arrear     Closed      48
# 3                 0       1      Monthly        Arrear     Closed      48
# 4                 0       1      Monthly        Arrear     Closed      48
# ...             ...     ...          ...           ...        ...     ...
# 1092595      128649  143389      Quatrly        Arrear     Closed      12
# 1092596      128650  143390  Half Yearly        Arrear     Closed      24
# 1092597      128650  143390  Half Yearly        Arrear     Closed      24
# 1092598      128651  143391  Half Yearly        Arrear     Closed      24
# 1092599      128653  143394  Half Yearly        Arrear     Active      35
#
#          AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new1.duplicated().sum()
# Out:
# 6926

# %%
df_new1.drop_duplicates()
# Out:
#          Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 0                 0       1      Monthly        Arrear     Closed      48
# 1                 0       1      Monthly        Arrear     Closed      48
# 2                 0       1      Monthly        Arrear     Closed      48
# 3                 0       1      Monthly        Arrear     Closed      48
# 4                 0       1      Monthly        Arrear     Closed      48
# ...             ...     ...          ...           ...        ...     ...
# 1092595      128649  143389      Quatrly        Arrear     Closed      12
# 1092596      128650  143390  Half Yearly        Arrear     Closed      24
# 1092597      128650  143390  Half Yearly        Arrear     Closed      24
# 1092598      128651  143391  Half Yearly        Arrear     Closed      24
# 1092599      128653  143394  Half Yearly        Arrear     Active      35
#
#          AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new=df_new1[df_new1['ACCOUNT-STATUS']=='Active']

# %%
df_new1['ACCOUNT-STATUS']
# Out:
# 0          Delinquent
# 1          Delinquent
# 2          Delinquent
# 3              Active
# 4              Active
#               ...
# 1092595        Closed
# 1092596        Active
# 1092597        Active
# 1092598        Active
# 1092599        Active
# Name: ACCOUNT-STATUS, Length: 1092600, dtype: object

# %%
df_new
# Out:
#          Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 3                 0       1      Monthly        Arrear     Closed      48
# 4                 0       1      Monthly        Arrear     Closed      48
# 5                 0       1      Monthly        Arrear     Closed      48
# 6                 0       1      Monthly        Arrear     Closed      48
# 7                 0       1      Monthly        Arrear     Closed      48
# ...             ...     ...          ...           ...        ...     ...
# 1092593      128649  143389      Quatrly        Arrear     Closed      12
# 1092596      128650  143390  Half Yearly        Arrear     Closed      24
# 1092597      128650  143390  Half Yearly        Arrear     Closed      24
# 1092598      128651  143391  Half Yearly        Arrear     Closed      24
# 1092599      128653  143394  Half Yearly        Arrear     Active      35
#
#          AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new.drop(['SELF-INDICATOR', 'MATCH-TYPE', 'ACCT-TYPE', 'CONTRIBUTOR-TYPE', 'DATE-REPORTED',
    'OWNERSHIP-IND', 'DISBURSED-DT', 'CLOSE-DT', 'LAST-PAYMENT-DATE',
    'CREDIT-LIMIT/SANC AMT', 'DISBURSED-AMT/HIGH CREDIT', 'INSTALLMENT-AMT', 'CURRENT-BAL',
    'INSTALLMENT-FREQUENCY', 'ASSET_CLASS', 'REPORTED DATE - HIST',
    'DPD - HIST', 'CUR BAL - HIST', 'AMT PAID - HIST','TENURE','AMT OVERDUE - HIST'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_3385/97918132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(['SELF-INDICATOR', 'MATCH-TYPE', 'ACCT-TYPE', 'CONTRIBUTOR-TYPE', 'DATE-REPORTED',

# %%
df_new
# Out:
#          Unnamed: 0      ID    Frequency InstlmentMode LoanStatus  Tenure  \
# 3                 0       1      Monthly        Arrear     Closed      48
# 4                 0       1      Monthly        Arrear     Closed      48
# 5                 0       1      Monthly        Arrear     Closed      48
# 6                 0       1      Monthly        Arrear     Closed      48
# 7                 0       1      Monthly        Arrear     Closed      48
# ...             ...     ...          ...           ...        ...     ...
# 1092593      128649  143389      Quatrly        Arrear     Closed      12
# 1092596      128650  143390  Half Yearly        Arrear     Closed      24
# 1092597      128650  143390  Half Yearly        Arrear     Closed      24
# 1092598      128651  143391  Half Yearly        Arrear     Closed      24
# 1092599      128653  143394  Half Yearly        Arrear     Active      35
#
#          AssetCost  AmountFinance  DisbursalAmount      EMI  ...  \
# ...

# %%
df_new.isna().sum()
# Out:
# Unnamed: 0             0
# ID                     0
# Frequency              0
# InstlmentMode          0
# LoanStatus             0
# Tenure                 0
# AssetCost              0
# AmountFinance          0
# DisbursalAmount        0
# EMI                    0
# DisbursalDate          0
# LTV                    0
# AGE                    0
# MonthlyIncome        461
# State                  0
# Top-up Month           0
# Feedback               0
# Target                 0
# new_emi1               0
# capable1               0
# ACCOUNT-STATUS         0
# OVERDUE-AMT_x          0
# WRITE-OFF-AMT      26548
# OVERDUE-AMT_y          0
# 0                      0
# dtype: int64

# %%
df_new.drop(['Unnamed: 0',0],axis=1)
# Out:
#              ID    Frequency InstlmentMode LoanStatus  Tenure  AssetCost  \
# 3             1      Monthly        Arrear     Closed      48     450000
# 4             1      Monthly        Arrear     Closed      48     450000
# 5             1      Monthly        Arrear     Closed      48     450000
# 6             1      Monthly        Arrear     Closed      48     450000
# 7             1      Monthly        Arrear     Closed      48     450000
# ...         ...          ...           ...        ...     ...        ...
# 1092593  143389      Quatrly        Arrear     Closed      12     650000
# 1092596  143390  Half Yearly        Arrear     Closed      24     470000
# 1092597  143390  Half Yearly        Arrear     Closed      24     470000
# 1092598  143391  Half Yearly        Arrear     Closed      24     460000
# 1092599  143394  Half Yearly        Arrear     Active      35     350000
#
#          AmountFinance  DisbursalAmount      EMI DisbursalDate  ...  \
# ...

# %%
df_new.to_csv('df_final')
